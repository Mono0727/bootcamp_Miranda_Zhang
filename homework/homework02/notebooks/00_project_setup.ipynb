# %% [markdown]
# # Environment & Config Check

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

from src.config import load_env, get_key

# %%
load_env()
print("API_KEY exists:", get_key("ALPHAVANTAGE_API_KEY") is not None)
# Out:
# API_KEY exists: True

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
arr * 2
# Out:
# array([ 2,  4,  6,  8, 10])
